# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('vaccination_tweets.csv')

# Check available columns
print(df.columns)
# Out:
# Index(['id', 'user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'retweets', 'favorites',
#        'is_retweet'],
#       dtype='object')

# %%
import pandas as pd

# Load the CSV file (replace with your actual file path)
data = pd.read_csv('linkedin_temp.csv')

print(data)
# Out:
#     Unnamed: 0                                               text  \
# 0            0      Woke up this morning to the news that I to...
# 1            1      Tata is hiring when world is firing !!!As ...
# 2            2      Ever wake up with a weird feeling?!Worked ...
# 3            3      I got laid off Today.I had a great job but...
# 4            4      For everyone impacted by recent layoffs, I...
# ..         ...                                                ...
# 284        284      Most corporate goal-setting programs are a...
# 285        285      What the ongoing crypto winter has in stor...
# 286        286      If you're asking yourself "why should I go...
# 287        287      Amazon's voice assistant division Alexa co...
# 288       _key                                               text
#
#                                                   role  num_reactions  \
# 0                      Lead Technical Sourcer                   1,907
# ...
